# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

# %%
train_10k_128_elemul = np.load("figures/train_elem_10000_128.npy")
val_10k_128_elemul = np.load("figures/val_elem_10000_128.npy")

# %%
plt.subplot(211)
plt.plot(train_10k_128_elemul,linewidth=2)
plt.title("training loss and val acc for best LR model, 1.28M param.")
plt.ylabel("training loss")
plt.subplot(212)
plt.plot(val_10k_128_elemul,linewidth=2)
plt.ylabel("val acc")
#plt.title("validation accuracy for best LR model")
plt.savefig("figures/best_LR.png")
plt.show()
#plt.plot(train_10k_128_concat,linewidth=1,label="best DNN model")
#plt.legend()
#plt.plot(train_2k_64_concat,'-.',markersize=1)
#plt.plot(train_2k_64_ele,markersize=1)

# %%
DNN_train_2k_64_elemul = np.load("figures/DNN_train_elemmul_10000_128.npy")
DNN_val_2k_64_elemul = np.load("figures/DNN_val_elemmul_10000_128.npy")

# %%
plt.subplot(211)
plt.plot(DNN_train_2k_64_elemul,linewidth=2)
plt.title("training loss and val acc for best DNN model, 1.29m param.")
plt.ylabel("training loss")
plt.subplot(212)
plt.plot(DNN_val_2k_64_elemul,linewidth=2)
plt.ylabel("val acc")
#plt.title("validation accuracy for best LR model")
plt.savefig("figures/best_DNN.png")
plt.show()
